# %%
# -*- coding: utf-8 -*-

import pandas as pd
import numpy as np
import xgboost as xgb
lb = 'age'
model_name = 'xgb_age.model'

def xgb_acc_score(preds, dtrain):
    y_true = dtrain.get_label()
    y_pred = np.argmax(preds, axis=1)
    return [('acc', np.mean(y_true == y_pred))]

df_lr = pd.read_csv('./data/tfidf_stack_10W.csv')
df_dbow = pd.read_csv('./data/dbowd2v_stack_10W.csv')

data_df = pd.read_csv( './data/all_v2.csv')

y = np.array(data_df[lb])
print(data_df.head())
print(y)

df = pd.concat([df_lr, df_dbow], axis=1)
print(df.head())

TR = 80000
esr = 100
evals = 1
num_class = len(np.unique(y))

X ,X_te= df.iloc[:TR], df.iloc[TR:]
y ,y_te= y[:TR],y[TR:]

ss = 0.5
mc = 0.8
md = 7
gm = 1
n_trees = 25

params = {
    "objective": "multi:softprob",
    "booster": "gbtree",
    "num_class": num_class,
    'max_depth': md,
    'min_child_weight': mc,
    'subsample': ss,
    'colsample_bytree': 1,
    'gamma': gm,
    "eta": 0.01,
    "lambda": 0,
    'alpha': 0,
    "silent": 1,
}

dtrain = xgb.DMatrix(X, y)
dvalid = xgb.DMatrix(X_te, y_te)
watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
bst = xgb.train(params, dtrain, n_trees, evals=watchlist, feval=xgb_acc_score, maximize=True,
                early_stopping_rounds=esr, verbose_eval=evals)

bst.save_model(model_name)
# Out:
#                                  Id  age  gender  Education  \
# 0  22DD920316420BE2DF8D6EE651BA174B    1       1          4
# 1  43CC3AF5A8D6430A3B572337A889AFE4    2       1          3
# 2  E97654BFF5570E2CCD433EA6128EAC19    4       1          0
# 3  6931EFC26D229CCFCEA125D3F3C21E57    4       2          3
# 4  E780470C3BB0D340334BD08CDCC3C71A    2       2          4
#
#                                                query
# 0  柔和双沟\t女生\t中财网首页 财经\thttp://pan.baidu.com/s/1pl...
# 1  广州厨宝烤箱\t世情薄,人情恶,雨送黄昏花易落,晓风干,泪痕\t厦门酒店用品批发市场\t我只...
# 2  钻石之泪耳机\t盘锦到沈阳\t旅顺公交\t辽宁阜新车牌\tbaidu\tk715\tk716...
# 3  最受欢迎狗狗排行榜\t舶怎么读\t场景描 写范例\t三维绘图软件\t枣和酸奶能一起吃吗\t好...
# 4  干槽症能自愈吗\t太太万岁叶舒心去没去美国\t干槽症\t右眼皮下面一直跳是怎么回事\t麦当劳...
# [1 2 4 ... 2 3 1]
#    tfidf_Education_0  tfidf_Education_1  tfidf_Education_2  tfidf_Education_3  \
# 0           0.158017           0.004670           0.005062           0.198774
# 1           0.131297           0.004623           0.003296           0.205626
# 2           0.104105           0.004617           0.006181           0.315600
# 3           0.175194           0.004402           0.004884           0.202898
# 4           0.036557           0.002213           0.006839           0.380662
#
#    tfidf_Education_4  tfidf_Education_5  tfidf_Education_6  tfidf_age_0  \
# 0           0.331189           0.203260           0.099028     0.022520
# 1           0.450168           0.180818           0.024173     0.016987
# 2           0.145219           0.391475           0.032804     0.026220
# 3           0.098855           0.177266           0.336501     0.020216
# 4           0.494143           0.065622           0.013965     0.009828
#
#    tfidf_age_1  tfidf_age_2  ...  dbowd2v_age_0  dbowd2v_age_1  dbowd2v_age_2  \
# 0     0.439665     0.054241  ...       0.016402       0.409195       0.238531
# 1     0.216246     0.307595  ...       0.024627       0.116282       0.274551
# 2     0.216586     0.207844  ...       0.008919       0.094933       0.492189
# 3     0.538483     0.016974  ...       0.025696       0.691714       0.036858
# 4     0.041942     0.539647  ...       0.004743       0.236486       0.651386
#
#    dbowd2v_age_3  dbowd2v_age_4  dbowd2v_age_5  dbowd2v_age_6  \
# 0       0.123948       0.168293       0.041253       0.002379
# 1       0.373231       0.159010       0.046834       0.005465
# 2       0.295996       0.077658       0.026514       0.003791
# 3       0.048699       0.164989       0.028168       0.003876
# 4       0.085319       0.016141       0.005278       0.000648
#
#    dbowd2v_gender_0  dbowd2v_gender_1  dbowd2v_gender_2
# 0          0.023834          0.201654          0.774511
# 1          0.018736          0.131429          0.849836
# 2          0.014578          0.894978          0.090444
# 3          0.040253          0.215620          0.744127
# 4          0.011017          0.088754          0.900229
#
# [5 rows x 34 columns]
# [0]	train-merror:0.393975	eval-merror:0.40475	train-acc:0.606025	eval-acc:0.59525
# Multiple eval metrics have been passed: 'eval-acc' will be used for early stopping.
#
# Will train until eval-acc hasn't improved in 100 rounds.
# [1]	train-merror:0.387775	eval-merror:0.39995	train-acc:0.612225	eval-acc:0.60005
# [2]	train-merror:0.3851	eval-merror:0.39585	train-acc:0.6149	eval-acc:0.60415
# [3]	train-merror:0.383975	eval-merror:0.3956	train-acc:0.616025	eval-acc:0.6044
# [4]	train-merror:0.383487	eval-merror:0.3929	train-acc:0.616513	eval-acc:0.6071
# [5]	train-merror:0.381925	eval-merror:0.39305	train-acc:0.618075	eval-acc:0.60695
# [6]	train-merror:0.38165	eval-merror:0.39275	train-acc:0.61835	eval-acc:0.60725
# [7]	train-merror:0.381525	eval-merror:0.3925	train-acc:0.618475	eval-acc:0.6075
# [8]	train-merror:0.381963	eval-merror:0.3919	train-acc:0.618038	eval-acc:0.6081
# [9]	train-merror:0.381413	eval-merror:0.39195	train-acc:0.618587	eval-acc:0.60805
# [10]	train-merror:0.381112	eval-merror:0.3912	train-acc:0.618888	eval-acc:0.6088
# [11]	train-merror:0.381225	eval-merror:0.39195	train-acc:0.618775	eval-acc:0.60805
# [12]	train-merror:0.38085	eval-merror:0.3913	train-acc:0.61915	eval-acc:0.6087
# [13]	train-merror:0.380987	eval-merror:0.3917	train-acc:0.619012	eval-acc:0.6083
# [14]	train-merror:0.38035	eval-merror:0.39145	train-acc:0.61965	eval-acc:0.60855
# [15]	train-merror:0.380388	eval-merror:0.3906	train-acc:0.619613	eval-acc:0.6094
# [16]	train-merror:0.380538	eval-merror:0.3909	train-acc:0.619463	eval-acc:0.6091
# [17]	train-merror:0.379838	eval-merror:0.39155	train-acc:0.620162	eval-acc:0.60845
# [18]	train-merror:0.3802	eval-merror:0.3907	train-acc:0.6198	eval-acc:0.6093
# [19]	train-merror:0.380075	eval-merror:0.3914	train-acc:0.619925	eval-acc:0.6086
# [20]	train-merror:0.380237	eval-merror:0.391	train-acc:0.619762	eval-acc:0.609
# [21]	train-merror:0.3806	eval-merror:0.39065	train-acc:0.6194	eval-acc:0.60935
# [22]	train-merror:0.380375	eval-merror:0.39115	train-acc:0.619625	eval-acc:0.60885
# [23]	train-merror:0.38	eval-merror:0.3906	train-acc:0.62	eval-acc:0.6094
# [24]	train-merror:0.379775	eval-merror:0.39115	train-acc:0.620225	eval-acc:0.60885
